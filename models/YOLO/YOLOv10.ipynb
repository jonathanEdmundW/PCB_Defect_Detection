# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataset Preparation

# %%
import os
import shutil

# %%
# %cd /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO
dataset = os.getcwd()
# !ls
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO
#  000000039769.jpg    '[1.1].ipynb'   Note.gdoc			     PCBData
# '[1.0]FINPRO.ipynb'  '[1.2].ipynb'   object_detection_crash_course   runs

# %%
if not os.path.exists("dataset"):
    print(True)
    # !mkdir dataset
# Out:
# True

# %%
# %cd /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData
ori_dataset = os.getcwd()
# !ls
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData
# group00041  group12100	group13000  group44000	group77000  group92000
# group12000  group12300	group20085  group50600	group90100

# %%
dataset_path = "/content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/dataset"
for (root,dirs,files) in os.walk(ori_dataset, topdown=True):
    if len(files) == 0:
        continue
    else:
        # %cd $root
        for file in files:
            if file.endswith("_test.jpg"):
                # !cp $file $dataset_path
            elif file.endswith(".txt"):
                # !cp $file $dataset_path
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group13000/group12100/12100_not
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group13000/group12100/12100
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group13000/13000_not
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group13000/13000
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group92000/92000_not
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group92000/92000
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group44000/44000_not
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group44000/44000
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group77000/77000_not
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/PCBData/group77000/77000
# ...

# %%
# %cd /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO
ori_dataset = os.getcwd()
# !ls
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO
#  000000039769.jpg    '[1.1].ipynb'   dataset	 object_detection_crash_course	 runs
# '[1.0]FINPRO.ipynb'  '[1.2].ipynb'   Note.gdoc	 PCBData

# %%
if not os.path.exists("data"):
    print(True)
    # !mkdir data

# %cd /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data
dataset = os.getcwd()
# !ls
# Out:
# True
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data

# %%
# %cd $dataset
os.mkdir("train")
os.mkdir("train/images")
os.mkdir("train/labels")
os.mkdir("valid")
os.mkdir("valid/images")
os.mkdir("valid/labels")
os.mkdir("test")
os.mkdir("test/images")
os.mkdir("test/labels")
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data

# %%
# %cd $dataset_path
# !ls
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/dataset
# 00041000_test.jpg  12100065_test.jpg  13000121_test.jpg  20085205_test.jpg  77000001_test.jpg
# 00041000.txt	   12100065.txt       13000121.txt	 20085205.txt	    77000001.txt
# 00041001_test.jpg  12100121_test.jpg  13000122_test.jpg  20085206_test.jpg  77000002_test.jpg
# 00041001.txt	   12100121.txt       13000122.txt	 20085206.txt	    77000002.txt
# 00041002_test.jpg  12100122_test.jpg  13000123_test.jpg  20085207_test.jpg  77000003_test.jpg
# 00041002.txt	   12100122.txt       13000123.txt	 20085207.txt	    77000003.txt
# 00041003_test.jpg  12100123_test.jpg  13000124_test.jpg  20085208_test.jpg  77000004_test.jpg
# 00041003.txt	   12100123.txt       13000124.txt	 20085208.txt	    77000004.txt
# 00041004_test.jpg  12100124_test.jpg  13000125_test.jpg  20085209_test.jpg  77000005_test.jpg
# 00041004.txt	   12100124.txt       13000125.txt	 20085209.txt	    77000005.txt
# ...

# %%
count = 0
data_path = "/content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data"
for files in os.listdir():
    cdir = os.getcwd()
    if files.endswith("_test.jpg") and count < 1200:
        shutil.move(src=os.path.join(cdir, files), dst=os.path.join(data_path, "train", "images"))
        txt_file = files.replace("_test.jpg", ".txt")
        shutil.move(src=os.path.join(cdir, txt_file), dst=os.path.join(data_path, "train", "labels"))
        count += 1
        continue
    elif files.endswith("_test.jpg") and count >= 1200 and count < 1350:
        shutil.move(src=os.path.join(cdir, files), dst=os.path.join(data_path, "valid", "images"))
        txt_file = files.replace("_test.jpg", ".txt")
        shutil.move(src=os.path.join(cdir, txt_file), dst=os.path.join(data_path, "valid", "labels"))
        count += 1
        continue
    elif files.endswith("_test.jpg") and count >= 1350 and count < 1500:
        shutil.move(src=os.path.join(cdir, files), dst=os.path.join(data_path, "test", "images"))
        txt_file = files.replace("_test.jpg", ".txt")
        shutil.move(src=os.path.join(cdir, txt_file), dst=os.path.join(data_path, "test", "labels"))
        count += 1
        continue

# %%
# %cd $dataset_path
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/dataset

# %%
files_count = 0
for files in os.listdir():
    if files.endswith("_test.jpg"):
        files_count += 1
files_count
# Out:
# 0

# %%
# %cd $dataset
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data

# %%
files_count = 0
for (root,dirs,files) in os.walk(dataset, topdown=True):
    if len(files) == 0:
        continue
    else:
        # %cd $root
        for file in files:
            if file.endswith("_test.jpg"):
                files_count += 1
files_count
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data/train/images
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data/train/labels
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data/valid/images
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data/valid/labels
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data/test/images
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data/test/labels
# 1500

# %% [markdown]
# # Environment Check

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# # Install YOLOV10, Supervision, Weights

# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# !pip install albumentations==1.4
# !pip install -q supervision roboflow
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.4 MB/s eta 0:00:00

# %%
# !mkdir -p {HOME}/weights
# !wget -P {HOME}/weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10m.pt
# !ls -lh {HOME}/weights
# Out:
# total 64M
# -rw-r--r-- 1 root root 64M May 26  2024 yolov10m.pt

# %% [markdown]
# # Custom Training

# %% [markdown]
# ## Download Data from Google Drive

# %%
# %cd /content
HOME = os.getcwd()
# Out:
# /content

# %%
os.mkdir("data")
# %cd /content/data
os.mkdir("images")
os.mkdir("images/train")
os.mkdir("images/valid")
os.mkdir("images/test")
os.mkdir("labels")
os.mkdir("labels/train")
os.mkdir("labels/valid")
os.mkdir("labels/test")
# Out:
# /content/data

# %%
data = os.getcwd()
dataset = '/content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/data'

# %%
from distutils.dir_util import copy_tree
import os

# %%
copy_tree(os.path.join(dataset, "train", "images"), os.path.join(data, "images", "train"))
copy_tree(os.path.join(dataset, "train", "labels"), os.path.join(data, "labels", "train"))
copy_tree(os.path.join(dataset, "valid", "images"), os.path.join(data, "images", "valid"))
copy_tree(os.path.join(dataset, "valid", "labels"), os.path.join(data, "labels", "valid"))
copy_tree(os.path.join(dataset, "test", "images"), os.path.join(data, "images", "test"))
copy_tree(os.path.join(dataset, "test", "labels"), os.path.join(data, "labels", "test"))
# Out:
# ['/content/data/labels/test/00041197.txt',
#  '/content/data/labels/test/00041201.txt',
#  '/content/data/labels/test/00041061.txt',
#  '/content/data/labels/test/00041050.txt',
#  '/content/data/labels/test/00041128.txt',
#  '/content/data/labels/test/00041129.txt',
#  '/content/data/labels/test/00041141.txt',
#  '/content/data/labels/test/00041206.txt',
#  '/content/data/labels/test/00041071.txt',
#  '/content/data/labels/test/00041064.txt',
#  '/content/data/labels/test/00041173.txt',
#  '/content/data/labels/test/00041126.txt',
#  '/content/data/labels/test/00041026.txt',
#  '/content/data/labels/test/00041079.txt',
#  '/content/data/labels/test/00041133.txt',
#  '/content/data/labels/test/00041167.txt',
#  '/content/data/labels/test/00041205.txt',
#  '/content/data/labels/test/00041040.txt',
#  '/content/data/labels/test/00041139.txt',
#  '/content/data/labels/test/00041214.txt',
#  '/content/data/labels/test/00041075.txt',
#  '/content/data/labels/test/00041017.txt',
# ...

# %%
files_count = 0
train_count = 0
valid_count = 0
test_count = 0
for (root,dirs,files) in os.walk(data, topdown=True):
    if len(files) == 0:
        continue
    else:
        # %cd $root
        cdir = os.getcwd()
        if cdir.find("train") != -1:
            for file in files:
                if file.endswith("_test.jpg"):
                    files_count += 1
                    train_count += 1
        elif cdir.find("valid") != -1:
            for file in files:
                if file.endswith("_test.jpg"):
                    files_count += 1
                    valid_count += 1
        elif cdir.find("test") != -1:
            for file in files:
                if file.endswith("_test.jpg"):
                    files_count += 1
                    test_count += 1
        else :
            for file in files:
                if file.endswith("_test.jpg"):
                    files_count += 1
print(files_count)
print(train_count)
print(valid_count)
print(test_count)
# Out:
# /content/data/images/valid
# /content/data/images/test
# /content/data/images/train
# /content/data/labels/valid
# /content/data/labels/test
# /content/data/labels/train
# 1500
# 1200
# 150
# 150

# %%
import yaml
# %cd $HOME
# Out:
# /content

# %%
# Sample data
data = {
    "names" : {0 : "background", 1 : "open", 2 : "short", 3 : "mousebite", 4 : "spur", 5 : "pin hole", 6 : "spurious copper"},
    "nc" : 7,
    "train": "/content/data/images/train",
    "val": "/content/data/images/valid",
    "test": "/content/data/images/test",
}

# Write to a YAML file
with open('data.yaml', 'w') as file:
    yaml.dump(data, file)

# %% [markdown]
# ## Training

# %%
# %cd /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/YOLOV5
# !ls
# Out:
# /content/drive/MyDrive/College/Semester_5/ComputerVision/FINPRO/YOLOV5
#  dataset.yaml   dataset.zip   PCB_defects_detection.ipynb  'PCB DEFECTS DETECTION YOLOV5.ipynb'

# %%
import shutil
shutil.copy('dataset.yaml', '/content/')
# Out:
# '/content/dataset.yaml'

# %%
import os
# %cd {HOME}
os.getcwd()
# Out:
# /content
# '/content'

# %%
# !unzip dataset.zip -d /content/
# Out:
# Archive:  dataset.zip
#    creating: /content/dataset/
#    creating: /content/dataset/images/
#    creating: /content/dataset/images/train/
#   inflating: /content/dataset/images/train/01_missing_hole_01.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_03.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_04.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_05.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_06.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_10.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_11.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_12.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_14.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_15.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_16.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_17.jpg
# ...

# %%
# !yolo task=detect mode=train epochs=10 batch=32 plots=True \
model={HOME}/weights/yolov10m.pt \
data={HOME}/dataset.yaml
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:733: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(file, map_location="cpu")
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    labels_correlogram.jpg  weights
# events.out.tfevents.1729865781.89f65c492b3e.2191.0  labels.jpg

# %%
from IPython.display import Image

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/results.png', width=600)
# Out:
# /content

# %% [markdown]
# ## Inference with Custom Model

# %%
import supervision as sv

# %%
from ultralytics import YOLOv10

model = YOLOv10(f'{HOME}/runs/detect/train2/weights/best.pt')

dataset = sv.DetectionDataset.from_yolo(
    images_directory_path=f"{dataset.location}/valid/images",
    annotations_directory_path=f"{dataset.location}/valid/labels",
    data_yaml_path=f"{dataset.location}/data.yaml"
)

bounding_box_annotator = sv.BoundingBoxAnnotator()
label_annotator = sv.LabelAnnotator()
# Out:
# ...
# SupervisionWarnings: BoundingBoxAnnotator is deprecated: `BoundingBoxAnnotator` is deprecated and has been renamed to `BoxAnnotator`. `BoundingBoxAnnotator` will be removed in supervision-0.26.0.

# %% [markdown]
# **NOTE:** Let's randomly select an image from our validation set and visualize the results.

# %%
import random

random_image = random.choice(list(dataset.images.keys()))
random_image = dataset.images[random_image]

results = model(source=random_image, conf=0.25)[0]
detections = sv.Detections.from_ultralytics(results)

annotated_image = bounding_box_annotator.annotate(
    scene=random_image, detections=detections)
annotated_image = label_annotator.annotate(
    scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
# Out:
# SupervisionWarnings: images is deprecated: `DetectionDataset.images` property is deprecated and will be removed in `supervision-0.26.0`. Iterate with `for path, image, annotation in dataset:` instead.
# SupervisionWarnings: images is deprecated: `DetectionDataset.images` property is deprecated and will be removed in `supervision-0.26.0`. Iterate with `for path, image, annotation in dataset:` instead.
# 0: 640x640 (no detections), 251.1ms
# Speed: 5.8ms preprocess, 251.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# While your deployment is processing, checkout the deployment docs to take your model to most destinations https://docs.roboflow.com/inference
